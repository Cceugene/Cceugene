# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('/JupyterNotbook/data/sleep_new.csv')
print(data.shape)
data
# Out:
# (51, 11)
#     Index        date  입면시각  기상시각 총 수면시간 기상방법  피로도    약  토막잠  꿈 기억  하지불안약
# 0     1.0  20220202.0   3.5  10.5      7  고양이  0.0  0.0  1.0   0.0    NaN
# 1     2.0  20220203.0   2.5    11    8.5   그냥  2.0  0.0  1.0   0.0    NaN
# 2     3.0  20220204.0     3    10      7   그냥  1.0  0.0  1.0   0.0    NaN
# 3     4.0  20220205.0     5    11      6   그냥  0.0  0.0  0.0   0.0    NaN
# 4     5.0  20220206.0     5    13      8   그냥  0.0  0.0  1.0   0.0    NaN
# 5     6.0  20220207.0     5   7.5    2.5   알람  1.0  0.0  1.0   1.0    NaN
# 6     7.0  20220208.0     3     8      5   알람  2.0  0.0  0.0   0.0    NaN
# 7     8.0  20220209.0     3     7      4   알람  3.0  0.0  0.0   0.0    NaN
# 8     9.0  20220210.0     2   7.5    5.5   출근  3.0  0.0  0.0   0.0    NaN
# 9    10.0  20220211.0     3   7.5    4.5   출근  4.0  0.0  1.0   0.0    NaN
# 10   11.0  20220212.0     4    14     10   그냥  1.0  0.0  1.0   0.0    NaN
# 11   12.0  20220213.0     5    13      8   그냥  2.0  0.0  1.0   0.0    NaN
# ...

# %%
#data.isnull()
data = data.drop(50, errors='ignore')
data = data.drop(['하지불안약', '약', 'Index'], axis=1, errors='ignore')

# %%
data.columns = ['date', 'sleep', 'wakeup', 'time', 'way', 'tired', 'dsleep', 'dream']

# %%
data['tired'].iloc[49] = 1.0

data['sleep'].iloc[30] = np.nan
data['sleep'].iloc[37] = np.nan
data['sleep'].iloc[40] = np.nan
data['wakeup'].iloc[30] = np.nan
data['wakeup'].iloc[37] = np.nan
data['wakeup'].iloc[40] = np.nan

data['time'].iloc[30] = 0
data['time'].iloc[37] = 0
data['time'].iloc[40] = 0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
data
# Out:
#           date sleep wakeup  time  way  tired  dsleep  dream
# 0   20220202.0   3.5   10.5     7  고양이    0.0     1.0    0.0
# 1   20220203.0   2.5     11   8.5   그냥    2.0     1.0    0.0
# 2   20220204.0     3     10     7   그냥    1.0     1.0    0.0
# 3   20220205.0     5     11     6   그냥    0.0     0.0    0.0
# 4   20220206.0     5     13     8   그냥    0.0     1.0    0.0
# 5   20220207.0     5    7.5   2.5   알람    1.0     1.0    1.0
# 6   20220208.0     3      8     5   알람    2.0     0.0    0.0
# 7   20220209.0     3      7     4   알람    3.0     0.0    0.0
# 8   20220210.0     2    7.5   5.5   출근    3.0     0.0    0.0
# 9   20220211.0     3    7.5   4.5   출근    4.0     1.0    0.0
# 10  20220212.0     4     14    10   그냥    1.0     1.0    0.0
# 11  20220213.0     5     13     8   그냥    2.0     1.0    0.0
# 12  20220214.0     7    7.5   0.5   알람    4.0     1.0    1.0
# 13  20220215.0     3      8     5   알람    4.0     1.0    0.0
# ...

# %%
data.to_csv("/JupyterNotbook/data/sleep_file.csv")

# %%
ls
# Out:
#  D 드라이브의 볼륨: SSD
#  볼륨 일련 번호: D498-E52F
#
#  D:\JupyterNotbook 디렉터리
#
# 2022-03-28  오전 12:38    <DIR>          .
# 2022-03-28  오전 12:38    <DIR>          ..
# 2022-03-28  오전 12:28    <DIR>          .ipynb_checkpoints
# 2022-03-23  오후 07:32    <DIR>          data
# 2022-03-27  오전 12:58    <DIR>          DataMining
# 2022-03-22  오전 12:09    <DIR>          DS
# 2022-03-22  오후 12:24            76,576 EDA_1.ipynb
# 2022-03-28  오전 12:38            54,828 EDA_2.ipynb
# 2022-03-28  오전 12:33             3,959 EDA_Scaling.ipynb
# 2022-03-28  오전 12:25             3,011 sleep_file.npy
#                4개 파일             138,374 바이트
#                6개 디렉터리  232,798,806,016 바이트 남음
