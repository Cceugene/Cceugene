# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/JupyterNotbook/data/sleep_file.csv')
df = df.drop(['Unnamed: 0', 'date'], axis=1)
df
# Out:
#     sleep  wakeup  time  way  tired  dsleep  dream
# 0     3.5    10.5   7.0  고양이    0.0     1.0    0.0
# 1     2.5    11.0   8.5   그냥    2.0     1.0    0.0
# 2     3.0    10.0   7.0   그냥    1.0     1.0    0.0
# 3     5.0    11.0   6.0   그냥    0.0     0.0    0.0
# 4     5.0    13.0   8.0   그냥    0.0     1.0    0.0
# 5     5.0     7.5   2.5   알람    1.0     1.0    1.0
# 6     3.0     8.0   5.0   알람    2.0     0.0    0.0
# 7     3.0     7.0   4.0   알람    3.0     0.0    0.0
# 8     2.0     7.5   5.5   출근    3.0     0.0    0.0
# 9     3.0     7.5   4.5   출근    4.0     1.0    0.0
# 10    4.0    14.0  10.0   그냥    1.0     1.0    0.0
# 11    5.0    13.0   8.0   그냥    2.0     1.0    0.0
# 12    7.0     7.5   0.5   알람    4.0     1.0    1.0
# 13    3.0     8.0   5.0   알람    4.0     1.0    0.0
# 14   11.0     8.0   7.0   출근    3.0     1.0    1.0
# 15    2.0    14.5  12.5   그냥    2.0     1.0    1.0
# 16    4.0    12.5   8.5   그냥    1.0     1.0    0.0
# ...

# %%
## 혼자 한 거
colors = list('ygcbrky')*7+['y']

for i in range(49):
    plt.scatter(x[i], y[i], c=colors[i])
    
plt.xlabel('time')
plt.ylabel('tired')
# Out:
# Text(0, 0.5, 'tired')
